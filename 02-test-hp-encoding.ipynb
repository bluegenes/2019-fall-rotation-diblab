# %% [markdown]
# # 02 - Add hydrophobic-polar protein encoding
#
# Explore an additional protein coding in sourmash (hydrophillic/hydrophobic encoding)

# %% [markdown]
# Sometimes we want to work with development versions of software tools. To keep these separate from the master versions, we need to make new conda environments to run them in.
#
# Because of how jupyter and conda interact, it's best to install software on the command line, and run jupyter notebook from within that conda environment. So execute the following on the command line to install sourmash with the hp encoding code and then launch a jupyter notebook.

# %% [markdown]
# ## Run this on the command line, prior to starting this notebook:
# ```
# # First, make a folder to work in:
# cd ~/2019-fall-rotation-diblab # change into your rotation folder
#
# #now download the czbiohub version of sourmash (need changes in PR #758 https://github.com/dib-lab/sourmash/pull/758)
# git clone https://github.com/czbiohub/sourmash czbiohub_sourmash #drops the code into new "czbiohub_sourmash" folder
#
# cd czbiohub_sourmash
# conda create -y -c bioconda -c conda-forge -n sourmash-hp jupyter bam2fasta python=3.7 # new environment with python=3.7 and jupyter
# cd czbiohub_sourmash
# pip install -e '.' # do a developer install of the code in this folder
#
# # activate the environment
# conda activate sourmash-hp
#
# #check that the software was installed
# sourmash
# sourmash compute -h
#
# # now let's run a jupyter notebook from this environment:
# cd ../ # change back out to main rotation directory
# jupyter notebook
# ```

# %%
# Now, let's check the sourmash compute options
# !sourmash compute -h
# Out:
# usage: sourmash [--protein] [--no-protein] [--dayhoff] [--no-dayhoff] [--hp]
#                 [--no-hp] [--dna] [--no-dna] [-q] [--input-is-protein]
#                 [-k KSIZES] [-n NUM_HASHES] [--check-sequence] [-f]
#                 [-o OUTPUT] [--singleton] [--merge MERGED] [--name-from-first]
#                 [--input-is-10x] [--count-valid-reads COUNT_VALID_READS]
#                 [--write-barcode-meta-csv WRITE_BARCODE_META_CSV]
#                 [-p PROCESSES] [--save-fastas SAVE_FASTAS]
#                 [--line-count LINE_COUNT] [--track-abundance]
#                 [--scaled SCALED] [--seed SEED] [--randomize]
#                 [--license LICENSE]
#                 [--rename-10x-barcodes RENAME_10X_BARCODES]
#                 [--barcodes-file BARCODES_FILE]
#                 filenames [filenames ...]
# sourmash: error: the following arguments are required: filenames

# %% [markdown]
# You should see a new option available for sourmash compute: `--hp`.
#
# You previously ran:
# + DNA k = 21, 31, 51; scaled = 2000
# + RNA k = 21, 31, 51; scaled = 2000
# + protein k = 7, 11, 17; scaled = 2000; no encoding
# + protein k = 7, 11, 17; scaled = 2000; dayhoff encoding
#
# You should now be able to compute the following signatures:
# + protein k = 7, 11, 17; scaled = 2000; hp encoding
#
# ### Task:
#   - Build signatures with hp encoding and sourmash compare matrices, as before. How does hp encoding compare to dayhoff encoding, or signatures built with the full AA alphabet? What about the DNA/RNA level? Can you build a visualization to showcase these differences?

# %% [markdown]
# For example, the following generates hp signatures for the bacteroides dataset:

# %%
# %%bash
# # ^this is magic code telling jupyter that this block is entirely bash code.
#
# mkdir -p sigs/bacteroides/protein/hp
# # generate hp signatures for bacteroides
# for infile in 2018-test_datasets/bacteroides/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 7,11,17 --input-is-protein --hp --track-abundance -o sigs/bacteroides/protein/hp/${out_name}.sig ${infile}; done
# # and build the compare matrix for k=7:
# sourmash compare -k 7 --csv sourmash_compare/bacteroides_k7_prot_hp_comp.csv sigs/bacteroides/protein/hp/*.sig
# Out:
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_000011065.1_ASM1106v1_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_
protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900032635.1_14555_6_27_protein.faa.gz
# calculated 6 signatures for 2030 sequences in 2018-test_datasets/bacteroides/protein/GCA_900032635.1_14555_6_27_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900032635.1_14555_6_27_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900104585.1_PRJEB16348_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900104585.1_PRJEB16348_protein.faa.gz
# Traceback (most recent call last):
#   File "/Users/tessa/miniconda3/envs/sourmash-hp/bin/sourmash", line 11, in <module>
#     load_entry_point('sourmash', 'console_scripts', 'sourmash')()
#   File "/Users/tessa/Dropbox/dib-lab/2019-fall-rotation-diblab/hp_encoding/czbiohub_sourmash/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/Users/tessa/Dropbox/dib-lab/2019-fall-rotation-diblab/hp_encoding/czbiohub_sourmash/sourmash/command_compute.py", line 335, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/Users/tessa/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/Users/tessa/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for '2018-test_datasets/bacteroides/protein/GCA_900104585.1_PRJEB16348_protein.faa.gz'
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 4750 sequences in 2018-test_datasets/bacteroides/protein/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900106755.1_IMG-taxon_2693429916_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 4847 sequences in 2018-test_datasets/bacteroides/protein/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900109385.1_IMG-taxon_2593339226_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 4892 sequences in 2018-test_datasets/bacteroides/protein/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900110645.1_IMG-taxon_2693429910_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 4090 sequences in 2018-test_datasets/bacteroides/protein/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900111425.1_IMG-taxon_2693429902_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 3057 sequences in 2018-test_datasets/bacteroides/protein/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900112795.1_IMG-taxon_2693429893_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 5087 sequences in 2018-test_datasets/bacteroides/protein/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900116355.1_IMG-taxon_2622736518_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900128475.1_PRJEB18047_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900128475.1_PRJEB18047_protein.faa.gz
# Traceback (most recent call last):
#   File "/Users/tessa/miniconda3/envs/sourmash-hp/bin/sourmash", line 11, in <module>
#     load_entry_point('sourmash', 'console_scripts', 'sourmash')()
#   File "/Users/tessa/Dropbox/dib-lab/2019-fall-rotation-diblab/hp_encoding/czbiohub_sourmash/sourmash/__main__.py", line 83, in main
#     cmd(sys.argv[2:])
#   File "/Users/tessa/Dropbox/dib-lab/2019-fall-rotation-diblab/hp_encoding/czbiohub_sourmash/sourmash/command_compute.py", line 335, in compute
#     for n, record in enumerate(screed.open(filename)):
#   File "/Users/tessa/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/screed/openscreed.py", line 39, in __init__
#     self.iter_fn = self.open_reader(filename, *args, **kwargs)
#   File "/Users/tessa/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/screed/openscreed.py", line 95, in open_reader
#     raise ValueError("unknown file format for '%s'" % filename)
# ValueError: unknown file format for '2018-test_datasets/bacteroides/protein/GCA_900128475.1_PRJEB18047_protein.faa.gz'
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 3335 sequences in 2018-test_datasets/bacteroides/protein/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900142325.1_IMG-taxon_2698536696_annotated_assembly_protein.sig. Note: signature license is CC0.
# == This is sourmash version 2.0.0a10.dev125+gbc9a050. ==
# == Please cite Brown and Irber (2016), doi:10.21105/joss.00027. ==
#
# WARNING: input is protein, turning off nucleotide hashing
# computing signatures for files: 2018-test_datasets/bacteroides/protein/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.faa.gz
# Computing signature for ksizes: [7, 11, 17]
# Computing only protein (and not nucleotide) signatures.
# Computing a total of 3 signature(s).
# Tracking abundance of input k-mers.
# ... reading sequences from 2018-test_datasets/bacteroides/protein/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.faa.gz
# calculated 6 signatures for 2333 sequences in 2018-test_datasets/bacteroides/protein/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.faa.gz
# saved signature(s) to sigs/bacteroides/protein/hp/GCA_900167375.1_IMG-taxon_2588254259_annotated_assembly_protein.sig. Note: signature license is CC0.
# usage: sourmash [-o OUTPUT] [--ignore-abundance] [-k KSIZE] [--protein]
#                 [--no-protein] [--dayhoff] [--no-dayhoff] [--hp] [--no-hp]
#                 [--dna] [--no-dna] [--traverse-directory] [--csv CSV]
#                 [-p PROCESSES] [-q]
#                 signatures [signatures ...]
# sourmash: error: argument --csv: can't open 'sourmash_compare/bacteroides_k7_prot_hp_comp.csv': [Errno 2] No such file or directory: 'sourmash_compare/bacteroides_k7_prot_hp_comp.csv'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-9-98802e6d72bc> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '# ^this is magic code telling jupyter that this block is entirely bash code.\n\n#For example, you can run:\n\nmkdir -p sigs/bacteroides/protein/hp\n# generate hp signatures for bacteroides\nfor infile in 2018-test_datasets/bacteroides/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 7,11,17 --input-is-protein --hp --track-abundance -o sigs/bacteroides/protein/hp/${out_name}.sig ${infile}; done\n# and build the compare matrix for k=7:\nsourmash compare -k 7 --csv sourmash_compare/bacteroides_k7_prot_hp_comp.csv sigs/bacteroides/protein/hp/*.sig\n')
#
# ~/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# </Users/tessa/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# ~/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/sourmash-hp/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'# ^this is magic code telling jupyter that this block is entirely bash code.\n\n#For example, you can run:\n\nmkdir -p sigs/bacteroides/protein/hp\n# generate hp signatures for bacteroides\nfor infile in 2018-test_datasets/bacteroides/protein/*faa.gz; do out_name=$(basename $infile .faa.gz); sourmash compute -k 7,11,17 --input-is-protein --hp --track-abundance -o sigs/bacteroides/protein/hp/${out_name}.sig ${infile}; done\n# and build the compare matrix for k=7:\nsourmash compare -k 7 --csv sourmash_compare/bacteroides_k7_prot_hp_comp.csv sigs/bacteroides/protein/hp/*.sig\n'' returned non-zero exit status 2.
